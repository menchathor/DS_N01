# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('_db_pokemon.csv')
##df = df.fillna(0)
# df.describe()
# df.shape
# df.head()
# df.index = df['pokedex_number']
# df = df.drop("pokedex_number", axis="columns")
##df_pok = df['generation'].value_counts(sort=False).reset_index().rename(columns={"generation":"Generación", "count":"Cantidad"})
# y = x.sum(axis="columns")
# print(x)
# print(gen_col)
pd.set_option('display.max_rows')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 12
#       1 df = pd.read_csv('_db_pokemon.csv')
#       2 ##df = df.fillna(0)
#       3 # df.describe()
#       4 # df.shape
#    (...)
#      10 # print(x)
#      11 # print(gen_col)
# ---> 12 pd.set_option('display.max_rows')
#      13 df
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File c:\Users\micha\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_config\config.py:157, in _set_option(*args, **kwargs)
#     155 nargs = len(args)
#     156 if not nargs or nargs % 2 != 0:
# --> 157     raise ValueError("Must provide an even number of non-keyword arguments")
# ...

# %%
mpl.style.use("bmh")
fig, ax = plt.subplots()
ax.bar(df_pok['Generación'], df_pok['Cantidad'])
ax.set_title("Cantidad de Pokemón por Generación")
ax.set_xlabel("Generación")
ax.set_ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %%
df.head(10)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4     ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 5     ['Blaze', 'Solar Power']         0.25           1.0             1.0
# 6     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 7     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 8     ['Torrent', 'Rain Dish']         1.00           1.0             1.0
# 9  ['Shield Dust', 'Run Away']         1.00           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# ...

# %%
fig, ax = plt.subplots()
ax.plot([1,3], [2,4])
ax.set_ylim([2,4])
ax.set_xlim([1,3])
ax.set_ylabel('y')
ax.set_xlabel('x')
ax.set_title('Grafico X vs Y')
ax.axhline(y=3, xmin=0, xmax=4, color='r')
ax.axvline(x=2.0, ymin=0, ymax=10, color='r')
